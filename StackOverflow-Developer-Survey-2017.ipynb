# %% [markdown]
# # Getting Job-Opportunities As A Software Developer

# %% [markdown]
# ## 1-Business Questions:
#
#     Question 1:-Is under-graduation from Computer Science necessary to get job-opportunities as a software developer?
#     Question 2:-How many years of programming experience needed to become a valid candidate for software developer role?
#     Question 3:-Which is the best website or platform to upload your profile or resume?

# %%
#importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
# %matplotlib inline

# %% [markdown]
# ## 2-Data Gathering and Understanding:

# %%
#loading dataset
df=pd.read_csv('./survey_results_public.csv')
df.head(5)
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
#finding number of rows and columns
df.shape
# Out:
# (51392, 154)

# %%
#finding name and number of columns with zero missing value
zero_miss_col=df.columns[df.isnull().sum()==0]
print(zero_miss_col)
print(zero_miss_col.shape[0])
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation'],
#       dtype='object')
# 7

# %%
#finding name and number of columns with greater than 50% missing value
large_miss_col=df.columns[(df.isnull().sum()/df.shape[0])*100>50]
print(large_miss_col)
print(large_miss_col.shape[0])
# Out:
# Index(['YearsCodedJobPast', 'WebDeveloperType', 'MobileDeveloperType',
#        'NonDeveloperType', 'ExCoderReturn', 'ExCoderNotForMe',
#        'ExCoderBalance', 'ExCoder10Years', 'ExCoderBelonged', 'ExCoderSkills',
#        'ExCoderWillNotCode', 'ExCoderActive', 'HoursPerWeek',
#        'AssessJobIndustry', 'AssessJobRole', 'AssessJobExp', 'AssessJobDept',
#        'AssessJobTech', 'AssessJobProjects', 'AssessJobCompensation',
#        'AssessJobOffice', 'AssessJobCommute', 'AssessJobRemote',
#        'AssessJobLeaders', 'AssessJobProfDevel', 'AssessJobDiversity',
#        'AssessJobProduct', 'AssessJobFinances', 'JobProfile', 'ResumePrompted',
#        'LearnedHiring', 'Currency', 'Overpaid', 'EducationImportant',
#        'TimeAfterBootcamp', 'CousinEducation', 'HaveWorkedFramework',
#        'WantWorkFramework', 'WantWorkDatabase', 'MetricAssess',
#        'InfluenceWorkstation', 'InfluenceHardware', 'InfluenceServers',
# ...

# %%
#finding name and number of columns with all missing value
all_miss_col=df.columns[df.isnull().sum()==df.shape[0]]
print(all_miss_col)
print(all_miss_col.shape[0])
# Out:
# Index([], dtype='object')
# 0

# %%
#finding name and number of quantitative columns
num_df=df.select_dtypes(include=['int','float'])
num_col=num_df.columns
print(num_col)
print(num_col.shape[0])
# Out:
# Index(['CareerSatisfaction', 'JobSatisfaction', 'HoursPerWeek',
#        'StackOverflowSatisfaction', 'Salary', 'ExpectedSalary'],
#       dtype='object')
# 6

# %%
#finding name and number of categorical columns
cat_df=df.select_dtypes(include=['object']).copy()
cat_col=cat_df.columns
print(cat_col)
print(cat_col.shape[0])
# Out:
# Index(['Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize', 'CompanyType',
#        ...
#        'StackOverflowBetter', 'StackOverflowWhatDo', 'StackOverflowMakeMoney',
#        'Gender', 'HighestEducationParents', 'Race', 'SurveyLong',
#        'QuestionsInteresting', 'QuestionsConfusing', 'InterestedAnswers'],
#       dtype='object', length=147)
# 147

# %% [markdown]
# #### Result of Data Gathering and Understanding:
#
# 1-Dataset contains 51392 rows and 154 columns.
#
# 2-There are 7 columns with no missing value.
#
# 3-There are 53 columns with missing value percentage greater than 50%.
#
# 4-There are 0 columns with all missing value.
#
# 5-There are 6 quantitative columns.
#
# 6-There are 147 categorical columns.

# %% [markdown]
# ## 3-Data Preparation:

# %% [markdown]
# ### 3.1-Dropping all the rows from the dataframe containing 'Not Employed' in their 'Employmnet Status column                 as all the above business question are interested in the respondents who are employed.

# %%
#dropping all rows from the dataframe containing 'Not Employed' in their 'Employmnet Status column
emp_df=df[(df['EmploymentStatus']=='Employed full-time') | (df['EmploymentStatus']=='Employed part-time')]
emp_df
# Out:
#        Respondent                                       Professional  \
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# 6               7  Professional non-developer who sometimes write...
# 7               8                             Professional developer
# 8               9                             Professional developer
# 10             11  Professional non-developer who sometimes write...
# 11             12                             Professional developer
# 13             14                             Professional developer
# 14             15                             Professional developer
# 17             18                             Professional developer
# 18             19                             Professional developer
# ...

# %% [markdown]
# ### 3.2-Imputing NaN value in the quantitative columns with their mean value

# %%
#imputing NaN value in the quantitative columns with their mean value
for col in num_col:
    emp_df[col].fillna(emp_df[col].mean(),inplace=True)
    
emp_df
# Out:
#        Respondent                                       Professional  \
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# 6               7  Professional non-developer who sometimes write...
# 7               8                             Professional developer
# 8               9                             Professional developer
# 10             11  Professional non-developer who sometimes write...
# 11             12                             Professional developer
# 13             14                             Professional developer
# 14             15                             Professional developer
# 17             18                             Professional developer
# 18             19                             Professional developer
# ...

# %% [markdown]
# ### 3.3- Imputing NaN value in Categorical column with their mode value.

# %%
#Imputing NaN value in Categorical column with their mode value.
for col in cat_col:
    emp_df[col].fillna(emp_df[col].mode()[0],inplace=True)
    
emp_df
# Out:
#        Respondent                                       Professional  \
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# 6               7  Professional non-developer who sometimes write...
# 7               8                             Professional developer
# 8               9                             Professional developer
# 10             11  Professional non-developer who sometimes write...
# 11             12                             Professional developer
# 13             14                             Professional developer
# 14             15                             Professional developer
# 17             18                             Professional developer
# 18             19                             Professional developer
# ...

# %% [markdown]
# ## 4-Analysis:

# %% [markdown]
# ### 4.1: Analysis for Question 1:-Is under-graduation from Computer Science necessary to get job-opportunities as a software developer?

# %%
#Analysis for Question 1
undergrad_count=emp_df.MajorUndergrad.value_counts()
undergrad_count
# Out:
# Computer science or software engineering                        21909
# Computer engineering or electrical/electronics engineering       3603
# Computer programming or Web development                          3164
# Information technology, networking, or system administration     1763
# A natural science                                                1541
# A non-computer-focused engineering discipline                    1439
# Mathematics or statistics                                        1361
# Something else                                                    818
# A humanities discipline                                           740
# A business discipline                                             689
# Management information systems                                    561
# Fine arts or performing arts                                      514
# A social science                                                  513
# ...

# %%
(undergrad_count/emp_df.shape[0]).plot(kind="bar");
plt.title("Under Graduation")
# Out:
# Text(0.5,1,'Under Graduation')

# %% [markdown]
# ### Result:
#
# From the above graph,we can see that more than 50% of the employed software developer have computer science background. But it is not necessary that a background in computer-science is necessary for becoming a software developer as observable from the above graph that many employed software developer have background other than computer science such as humanity,psychology,natural science,busines,health science etc.

# %% [markdown]
# ### 4.2:Analysis for Question 2:-How many years of programming experience needed to become a valid candidate for software developer role?

# %%
#Analysis for question 2
prog_exp=emp_df.YearsProgram.value_counts()
prog_exp
# Out:
# 20 or more years    7193
# 4 to 5 years        2780
# 5 to 6 years        2742
# 9 to 10 years       2686
# 3 to 4 years        2460
# 6 to 7 years        2291
# 7 to 8 years        2010
# 2 to 3 years        1991
# 10 to 11 years      1849
# 14 to 15 years      1734
# 8 to 9 years        1572
# 1 to 2 years        1533
# 15 to 16 years      1442
# 11 to 12 years      1190
# 12 to 13 years      1129
# 13 to 14 years       954
# 16 to 17 years       899
# 19 to 20 years       864
# 17 to 18 years       736
# Less than a year     723
# 18 to 19 years       550
# Name: YearsProgram, dtype: int64

# %%
(prog_exp/emp_df.shape[0]).plot(kind='bar')

# %% [markdown]
# ### Result:
# From the above graph it is not clear how many years of programming experience is required for getting job as software developer as we can see there are more(2460) employed software developer with programming experience of 3-4 years than less(2291) employed software developer having programming experience of 6-7 years.

# %% [markdown]
# ### 4.3:Analysis of Question 3:-Which is the best website or platform to upload your profile or resume?

# %%
#Analysis of question 3
platform_count=emp_df.JobProfile.value_counts()
platform_count
# Out:
# LinkedIn                                                                                     30730
# LinkedIn; Other                                                                               1276
# Other                                                                                          781
# LinkedIn; Xing                                                                                 517
# Indeed; LinkedIn                                                                               504
# Xing                                                                                           491
# LinkedIn; Naukri                                                                               446
# LinkedIn; Monster                                                                              439
# Glassdoor; LinkedIn                                                                            360
# ...

# %%
def total_count(df, col1, col2, look_for):
    '''
    INPUT:
    df - the pandas dataframe you want to search
    col1 - the column name you want to look through
    col2 - the column you want to count values from
    look_for - a list of strings you want to search for in each row of df[col]

    OUTPUT:
    new_df - a dataframe of each look_for with the count of how often it shows up
    '''
    new_df = defaultdict(int)
    #loop through list of ed types
    for val in look_for:
        #loop through rows
        for idx in range(df.shape[0]):
            #if the ed type is in the row add 1
            if val in df[col1][idx]:
                new_df[val] += int(df[col2][idx])
    new_df = pd.DataFrame(pd.Series(new_df)).reset_index()
    new_df.columns = [col1, col2]
    new_df.sort_values('count', ascending=False, inplace=True)
    return new_df

# %%
possible_vals = ["LinkedIn","Xing","Indeed","Glassdoor","Hired.com","TripleByte","Monster","Dice","JobSite.co.uk","Talent.io","Reed.co.uk","Total_Jobs","Remix_jobs",
                 "StepStone","Naukri","Pracuj","Other"]

def clean_and_plot(df, title='Platform For Maintaining Profile,Resume', plot=True):
    '''
    INPUT 
        df - a dataframe holding the CousinEducation column
        title - string the title of your plot
        axis - axis object
        plot - bool providing whether or not you want a plot back
        
    OUTPUT
        study_df - a dataframe with the count of how many individuals
        Displays a plot of pretty things related to the CousinEducation column.
    '''
    platform = df['JobProfile'].value_counts().reset_index()
    platform.rename(columns={'index': 'platform', 'JobProfile': 'count'}, inplace=True)
    platform_df = total_count(platform, 'platform', 'count', possible_vals)

    platform_df.set_index('platform', inplace=True)
    if plot:
        (platform_df/platform_df.sum()).plot(kind='bar', legend=None);
        plt.title(title);
        plt.show()
    props_platform_df = platform_df/platform_df.sum()
    return props_platform_df
    
props_df = clean_and_plot(emp_df)

# %% [markdown]
# ### Result:
# From the above plot, we can see that more than 70% of the employed software developer maintains their profile,cv or resume on Indeed.So,Indeed is the best platform to maintains profile or resume for job searching.

# %% [markdown]
# ## 5- Results:
# 1-It is not necessary to do under-graduation in Computer Science to get Software Developer job.Peoples with under-graduation in any field can become software developer.
#
# 2-There is no threshold on required years of programming experience one must have to get job-opportunities as software developer.As we can see from the plot there are more employed software developer with 3-4 years programming experience than  employed software developer having programming experience of 6-7 years.
#
# 3-More than 70% of the employed software developer maintains their profile,cv or resume on Indeed.So,Indeed is the best platform to maintains profile or resume for job searching.
